# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
zip = gpd.read_file('zipcodes.geojson')
zip['po_name'] = zip['po_name'].str.upper()
zip
# Out:
#       zip objectid         po_name      shape_stlength        shape_starea  \
# 0   37115        1         MADISON  178783.02488886821  596553400.57885742
# 1   37216        3       NASHVILLE  75820.997821400058  188884682.28344727
# 2   37204        9       NASHVILLE  93180.292250425613  200664795.51708984
# 3   37027       11       BRENTWOOD   159760.6942933173  174978422.04101562
# 4   37064       18        FRANKLIN  28995.828320601937  46969608.005737305
# 5   37143       23          PEGRAM  7047.8267580476522   1900364.756652832
# 6   37080       42         JOELTON  2319.8074237329579  56522.611450195313
# 7   37221       17       NASHVILLE   241372.3112694624  1266395059.4877319
# 8   37072       47  GOODLETTSVILLE  225242.45424953851  1094968706.7701416
# 9   37212       54       NASHVILLE  58759.243654332378  73920091.147705078
# 10  37135        7     NOLENSVILLE   69742.56063023665  74707266.403198242
# ...

# %%
zip.plot()
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(figsize=(25,6))
zip.plot(ax = ax);

# %%
fig, ax = plt.subplots(figsize=(16,4))
zip.plot(ax = ax)
ax.axis('off');

# %%
inc = pd.read_csv('data/h_income/income.csv')

inc.head()
# Out:
#           geoid   name  B19001001  B19001001, Error  B19001002  \
# 0  86000US37013  37013      35597               617       1424
# 1  86000US37015  37015       6673               279        421
# 2  86000US37027  37027      19950               382        460
# 3  86000US37062  37062       4040               188        119
# 4  86000US37064  37064      21640               472        771
#
#    B19001002, Error  B19001003  B19001003, Error  B19001004  B19001004, Error  \
# 0               311       1023               239       1197               263
# 1               164        256               101        115                60
# 2               166        173                94        246                97
# 3                53        122                54        138                71
# 4               259        302               127        623               192
#
#    ...  B19001013  B19001013, Error  B19001014  B19001014, Error  B19001015  \
# ...

# %%
inc.rename({3:'total'}, axis='columns')
inc.head()
# Out:
#           geoid   name  B19001001  B19001001, Error  B19001002  \
# 0  86000US37013  37013      35597               617       1424
# 1  86000US37015  37015       6673               279        421
# 2  86000US37027  37027      19950               382        460
# 3  86000US37062  37062       4040               188        119
# 4  86000US37064  37064      21640               472        771
#
#    B19001002, Error  B19001003  B19001003, Error  B19001004  B19001004, Error  \
# 0               311       1023               239       1197               263
# 1               164        256               101        115                60
# 2               166        173                94        246                97
# 3                53        122                54        138                71
# 4               259        302               127        623               192
#
#    ...  B19001013  B19001013, Error  B19001014  B19001014, Error  B19001015  \
# ...

# %%
zip2 = zip.groupby(['Date','Keyword'],as_index=False).agg({'Views': 'sum'})

# %%
zip['zip'] = zip['zip'].astype(str)
inc['name'] = inc['name'].astype(str)

zip = pd.merge(left = zip, right = inc, 
                    left_on = 'zip', right_on = 'name')
zip.head()
# Out:
#      zip objectid    po_name      shape_stlength        shape_starea  \
# 0  37115        1    MADISON  178783.02488886821  596553400.57885742
# 1  37216        3  NASHVILLE  75820.997821400058  188884682.28344727
# 2  37204        9  NASHVILLE  93180.292250425613  200664795.51708984
# 3  37027       11  BRENTWOOD   159760.6942933173  174978422.04101562
# 4  37027       31  BRENTWOOD  3116.4327152718852  304596.06201171875
#
#                                             geometry         geoid   name  \
# 0  MULTIPOLYGON (((-86.68725 36.31821, -86.68722 ...  86000US37115  37115
# 1  MULTIPOLYGON (((-86.73451 36.23774, -86.73425 ...  86000US37216  37216
# 2  MULTIPOLYGON (((-86.77914 36.13424, -86.77923 ...  86000US37204  37204
# 3  MULTIPOLYGON (((-86.81258 36.06319, -86.81263 ...  86000US37027  37027
# 4  MULTIPOLYGON (((-86.72012 36.00886, -86.72012 ...  86000US37027  37027
#
#    B19001001  B19001001, Error  ...  B19001013  B19001013, Error  B19001014  \
# ...

# %%
fig, ax = plt.subplots(figsize=(16,4))
zip.plot(column = 'B19001016', 
              cmap = 'GnBu', 
              edgecolor = 'black', 
              legend = True,
              ax = ax)
plt.title('Incomes in the ___ range By Zipcode, 2019', fontsize = 14)
ax.axis('off');
